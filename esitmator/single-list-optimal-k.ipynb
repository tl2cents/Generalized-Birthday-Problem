# %%
# codes to verify our Lemma 3 and Theorem 1
def expected_sol(n, k):
    ell = n/(k+1)
    N = ceil(2^(ell + 1))
    return RR(2*binomial(N, 2^k)*factorial(2^k)/N^(2^k))

def fast_expected_sol(n, k):
    ell = n/(k+1)
    N = ceil(2^(ell + 1))
    res = 1
    for i in range(2^k):
        res*= 1 - i/N
    return RR(2*res)

def approx_expected_sol(n, k):
    ell = n/(k+1)
    N = ceil(2^(ell + 1))
    return RR(2 * e**(-(2^(2*k) - 2^k)/(2*N)))

def single_list_k_upper_bound(n):
    return sqrt(n/2 + 1)

# %%
Equihash_Parameter_Set = [
    (200, 9),
    (150, 5),
    (144,5),
    (96, 5),
    (128, 7),
    (160, 9),
    (176, 10),
    (192, 11),
    (96, 3),
    (192, 7),
    (240, 9),
    (96, 2),
    (288, 8)
]

print("Estimating Equihash parameters.")
print("*"*48)
for n,k in Equihash_Parameter_Set:
    k_upper_bound = floor(single_list_k_upper_bound(n))
    print(f"{n = },  {k = }, {k_upper_bound = }")
    print("Estimating solution numbers: ")
    print(f"{expected_sol(n,k) = }")
    print(f"{fast_expected_sol(n,k) = }")
    print(f"{approx_expected_sol(n,k) = }")
    print("*"*48)
# Out:
# Estimating Equihash parameters.
# ************************************************
# n = 200,  k = 9, k_upper_bound = 10
# Estimating solution numbers:
# expected_sol(n,k) = 1.87904595799147
# fast_expected_sol(n,k) = 1.87904595799147
# approx_expected_sol(n,k) = 1.87905548851816
# ************************************************
# n = 150,  k = 5, k_upper_bound = 8
# Estimating solution numbers:
# expected_sol(n,k) = 1.99998521810041
# fast_expected_sol(n,k) = 1.99998521810041
# approx_expected_sol(n,k) = 1.99998521810272
# ************************************************
# n = 144,  k = 5, k_upper_bound = 8
# Estimating solution numbers:
# expected_sol(n,k) = 1.99997043630545
# fast_expected_sol(n,k) = 1.99997043630545
# approx_expected_sol(n,k) = 1.99997043631470
# ************************************************
# n = 96,  k = 5, k_upper_bound = 7
# Estimating solution numbers:
# expected_sol(n,k) = 1.99244533852132
# fast_expected_sol(n,k) = 1.99244533852132
# approx_expected_sol(n,k) = 1.99244594259481
# ************************************************
# n = 128,  k = 7, k_upper_bound = 8
# Estimating solution numbers:
# expected_sol(n,k) = 1.87970593070711
# fast_expected_sol(n,k) = 1.87970593070711
# approx_expected_sol(n,k) = 1.87974374520609
# ************************************************
# n = 160,  k = 9, k_upper_bound = 9
# Estimating solution numbers:
# expected_sol(n,k) = 0.736238985269018
# fast_expected_sol(n,k) = 0.736238985269018
# approx_expected_sol(n,k) = 0.737197315672744
# ************************************************
# n = 176,  k = 10, k_upper_bound = 9
# Estimating solution numbers:
# expected_sol(n,k) = 0.0363926377569754
# fast_expected_sol(n,k) = 0.0363926377569754
# approx_expected_sol(n,k) = 0.0367746485450116
# ************************************************
# n = 192,  k = 11, k_upper_bound = 9
# Estimating solution numbers:
# expected_sol(n,k) = 2.08574573318264e-7
# fast_expected_sol(n,k) = 2.08574573318264e-7
# approx_expected_sol(n,k) = 2.26835598067454e-7
# ************************************************
# n = 96,  k = 3, k_upper_bound = 7
# Estimating solution numbers:
# expected_sol(n,k) = 1.99999833107052
# fast_expected_sol(n,k) = 1.99999833107052
# approx_expected_sol(n,k) = 1.99999833107064
# ************************************************
# n = 192,  k = 7, k_upper_bound = 9
# Estimating solution numbers:
# expected_sol(n,k) = 1.99951559150601
# fast_expected_sol(n,k) = 1.99951559150601
# approx_expected_sol(n,k) = 1.99951559211949
# ************************************************
# n = 240,  k = 9, k_upper_bound = 11
# Estimating solution numbers:
# expected_sol(n,k) = 1.99221789883267
# fast_expected_sol(n,k) = 1.99221789883267
# approx_expected_sol(n,k) = 1.99221793829890
# ************************************************
# n = 96,  k = 2, k_upper_bound = 7
# Estimating solution numbers:
# expected_sol(n,k) = 1.99999999860302
# fast_expected_sol(n,k) = 1.99999999860302
# approx_expected_sol(n,k) = 1.99999999860302
# ************************************************
# n = 288,  k = 8, k_upper_bound = 12
# Estimating solution numbers:
# expected_sol(n,k) = 1.99999240042215
# fast_expected_sol(n,k) = 1.99999240042215
# approx_expected_sol(n,k) = 1.99999240042223
# ************************************************

# %%
print("Verify The Upper Bound of k.")
print("*"*48)
for n in range(256, 4096+1, 256):
    k_upper_bound = floor(single_list_k_upper_bound(n))
    print(f"{n = } {k_upper_bound = }")
    print("Estimating solution numbers: ")
    if k_upper_bound <= 18:
        # avoid too long-time accurate compuation
        print(f"{fast_expected_sol(n, k_upper_bound) = }")
        print(f"{fast_expected_sol(n, k_upper_bound + 1) = }")
    print(f"{approx_expected_sol(n, k_upper_bound) = }")
    print(f"{approx_expected_sol(n, k_upper_bound + 1) = }")
    print("*"*48)
# Out:
# Verify The Upper Bound of k.
# ************************************************
# n = 256 k_upper_bound = 11
# Estimating solution numbers:
# fast_expected_sol(n, k_upper_bound) = 1.34506112883775
# fast_expected_sol(n, k_upper_bound + Integer(1)) = 0.0141146711014787
# approx_expected_sol(n, k_upper_bound) = 1.34513004978854
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.0141711416589796
# ************************************************
# n = 512 k_upper_bound = 16
# Estimating solution numbers:
# fast_expected_sol(n, k_upper_bound) = 0.795696825791605
# fast_expected_sol(n, k_upper_bound + Integer(1)) = 0.0000156452646976906
# approx_expected_sol(n, k_upper_bound) = 0.795703701918655
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.0000156562706132877
# ************************************************
# n = 768 k_upper_bound = 19
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.65480465912263
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.135518022843089
# ************************************************
# n = 1024 k_upper_bound = 22
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.68037049686642
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.160944673028834
# ************************************************
# n = 1280 k_upper_bound = 25
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.30611488628487
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.00480225609753946
# ************************************************
# n = 1536 k_upper_bound = 27
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.74217789158104
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.257887475077967
# ************************************************
# n = 1792 k_upper_bound = 29
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.85513619888733
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.637356734060404
# ************************************************
# n = 2048 k_upper_bound = 32
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 0.766658324655410
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 2.50044579161426e-6
# ************************************************
# n = 2304 k_upper_bound = 33
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.85813911702635
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.648543694132696
# ************************************************
# n = 2560 k_upper_bound = 35
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.78142363846510
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.346092269889436
# ************************************************
# n = 2816 k_upper_bound = 37
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.58524400493117
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.0622436220225747
# ************************************************
# n = 3072 k_upper_bound = 39
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.12614241799229
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.000442503144657146
# ************************************************
# n = 3328 k_upper_bound = 40
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.78978979791837
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.366931240820072
# ************************************************
# n = 3584 k_upper_bound = 42
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.35058633801563
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.00582979616609349
# ************************************************
# n = 3840 k_upper_bound = 43
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.80340766174438
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.408912586218863
# ************************************************
# n = 4096 k_upper_bound = 45
# Estimating solution numbers:
# approx_expected_sol(n, k_upper_bound) = 1.23120184759247
# approx_expected_sol(n, k_upper_bound + Integer(1)) = 0.00147046725215063
# ************************************************

# %%
note ="""
The expected number of solutions can also be verified in single-list algorithm.
This has already been done in work "On Iterative Collision Search for LPN and Subset Sum."
We provide the proof of concept python codes for verification.
"""
